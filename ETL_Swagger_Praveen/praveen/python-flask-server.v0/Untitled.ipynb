# %%
#!/usr/bin/env python3

import connexion

from swagger_server import encoder


def main():
    app = connexion.App(__name__, specification_dir='swagger_server/swagger/')
    app.app.json_encoder = encoder.JSONEncoder
    app.add_api('swagger.yaml', arguments={'title': 'Data Ingestion Framework'})
    app.run(port=8080)


if __name__ == '__main__':
    main()
# Out:
# Failed to add operation for DELETE /v2/rules/delete
# ---------------------------------------------------------------------------
# ResolverError                             Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/connexion/apis/abstract.py in add_paths(self, paths)
#     206                 try:
# --> 207                     self.add_operation(path, method)
#     208                 except ResolverError as err:
#
# /usr/local/lib/python3.6/site-packages/connexion/apis/abstract.py in add_operation(self, path, method)
#     170             uri_parser_class=self.options.uri_parser_class,
# --> 171             pass_context_arg_name=self.pass_context_arg_name
#     172         )
#
# /usr/local/lib/python3.6/site-packages/connexion/operations/__init__.py in make_operation(spec, *args, **kwargs)
#       7 def make_operation(spec, *args, **kwargs):
# ----> 8     return spec.operation_cls.from_spec(spec, *args, **kwargs)
#
# /usr/local/lib/python3.6/site-packages/connexion/operations/swagger2.py in from_spec(cls, spec, api, path, method, resolver, *args, **kwargs)
#     136             *args,
# --> 137             **kwargs
#     138         )
#
# /usr/local/lib/python3.6/site-packages/connexion/operations/swagger2.py in __init__(self, api, method, path, operation, resolver, app_produces, app_consumes, path_parameters, app_security, security_definitions, definitions, parameter_definitions, response_definitions, validate_responses, strict_validation, randomize_endpoint, validator_map, pythonic_params, uri_parser_class, pass_context_arg_name)
#      95             uri_parser_class=uri_parser_class,
# ---> 96             pass_context_arg_name=pass_context_arg_name
#      97         )
#
# /usr/local/lib/python3.6/site-packages/connexion/operations/abstract.py in __init__(self, api, method, path, operation, resolver, app_security, security_schemes, validate_responses, strict_validation, randomize_endpoint, validator_map, pythonic_params, uri_parser_class, pass_context_arg_name)
#      97         self._operation_id = self._operation.get("operationId")
# ---> 98         self._resolution = resolver.resolve(self)
#      99         self._operation_id = self._resolution.operation_id
#
# /usr/local/lib/python3.6/site-packages/connexion/resolver.py in resolve(self, operation)
#      39         operation_id = self.resolve_operation_id(operation)
# ---> 40         return Resolution(self.resolve_function_from_operation_id(operation_id), operation_id)
#      41
#
# /usr/local/lib/python3.6/site-packages/connexion/resolver.py in resolve_function_from_operation_id(self, operation_id)
#      65         except (AttributeError, ValueError) as e:
# ---> 66             raise ResolverError(str(e), sys.exc_info())
#      67
#
# ResolverError: <ResolverError: Empty module name>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-ed052fae0296> in <module>
#      14
#      15 if __name__ == '__main__':
# ---> 16     main()
#
# <ipython-input-6-ed052fae0296> in main()
#       9     app = connexion.App(__name__, specification_dir='swagger_server/swagger/')
#      10     app.app.json_encoder = encoder.JSONEncoder
# ---> 11     app.add_api('swagger.yaml', arguments={'title': 'Data Ingestion Framework'})
#      12     app.run(port=8080)
#      13
#
# /usr/local/lib/python3.6/site-packages/connexion/apps/flask_app.py in add_api(self, specification, **kwargs)
#      52
#      53     def add_api(self, specification, **kwargs):
# ---> 54         api = super(FlaskApp, self).add_api(specification, **kwargs)
#      55         self.app.register_blueprint(api.blueprint)
#      56         return api
#
# /usr/local/lib/python3.6/site-packages/connexion/apps/abstract.py in add_api(self, specification, base_path, arguments, auth_all_paths, validate_responses, strict_validation, resolver, resolver_error, pythonic_params, pass_context_arg_name, options, validator_map)
#     153                            pythonic_params=pythonic_params,
#     154                            pass_context_arg_name=pass_context_arg_name,
# --> 155                            options=api_options.as_dict())
#     156         return api
#     157
#
# /usr/local/lib/python3.6/site-packages/connexion/apis/abstract.py in __init__(self, specification, base_path, arguments, validate_responses, strict_validation, resolver, auth_all_paths, debug, resolver_error_handler, validator_map, pythonic_params, pass_context_arg_name, options)
#     107             self.add_swagger_ui()
#     108
# --> 109         self.add_paths()
#     110
#     111         if auth_all_paths:
#
# /usr/local/lib/python3.6/site-packages/connexion/apis/abstract.py in add_paths(self, paths)
#     212                         self._add_resolver_error_handler(method, path, err)
#     213                     else:
# --> 214                         self._handle_add_operation_error(path, method, err.exc_info)
#     215                 except Exception:
#     216                     # All other relevant exceptions should be handled as well.
#
# /usr/local/lib/python3.6/site-packages/connexion/apis/abstract.py in _handle_add_operation_error(self, path, method, exc_info)
#     226         else:
#     227             logger.error(error_msg)
# --> 228             six.reraise(*exc_info)
#     229
#     230     @classmethod
#
# /usr/local/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /usr/local/lib/python3.6/site-packages/connexion/resolver.py in resolve_function_from_operation_id(self, operation_id)
#      59         """
#      60         try:
# ---> 61             return self.function_resolver(operation_id)
#      62         except ImportError as e:
#      63             msg = 'Cannot resolve operationId "{}"! Import error was "{}"'.format(operation_id, str(e))
#
# /usr/local/lib/python3.6/site-packages/connexion/utils.py in get_function_from_name(function_name)
#      86     while not module:
#      87         try:
# ---> 88             module = importlib.import_module(module_name)
#      89         except ImportError as import_error:
#      90             last_import_error = import_error
#
# /usr/lib64/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib64/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib64/python3.6/importlib/_bootstrap.py in _sanity_check(name, package, level)
#
# ValueError: Empty module name
